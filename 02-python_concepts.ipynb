# %% [markdown]
# ### Python Programming Concepts

# %% [markdown]
# #### 1. Create a variable to store the value 500 for sales

# %%
from calendar import day_name
from random import random

sales = 500
sales
# Out:
# 500

# %% [markdown]
# #### 2. Create a variable to store several values:
# * sales: 500, 475, 625
# * integers 1 - 9

# %%
sales = [500, 475, 625]
sales.pop()
# Out:
# 625

# %%
integers = list(range(10,1,-1))
integers
# Out:
# [10, 9, 8, 7, 6, 5, 4, 3, 2]

# %% [markdown]
# #### 3. Create a variable to store the names and email addresses for a number of customers
# * John, john@some.com; Ann, ann@some.com

# %%
Customer_Info = [John, john@some.com, Ann, ann@some.com]
Customer_Info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Customer_Info = [John, john@some.com, Ann, ann@some.com]
#       2 Customer_Info
#
# NameError: name 'John' is not defined

# %% [markdown]
# #### 4. Use Python to generate a random value based on each of following:
# 1. between 0 and 1
# 2. the standard normal distribution (rounded to two decimal places)
# 3. a value between 1 and 10
# 4. either H or T

# %%
import random
random.choice([0, 1])
# Out:
# 0

# %%
random(norm.distr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 random(norm.distr)
#
# NameError: name 'norm' is not defined

# %%
random.__init__(1-10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 random.__init__(1-10)
#
# TypeError: module() argument 'name' must be str, not int

# %%
random.__name__(H,T)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 random.__name__(H,T)
#
# NameError: name 'H' is not defined

# %% [markdown]
# #### 5. Use Python to determine your current working directory

# %%
cd
# Out:
# /Users/tian_le

# %% [markdown]
# #### 6. Use Python to determine how many days until New Year's Day

# %%
day_name(New Year)
# Out:
#   Cell In[15], line 1
#     day_name(New Year)
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# #### 7. Write a short program that displays the future value of 1,000 earning 5%  at the end of each year for the next 5 years

# %%
C = 1000
r = 0.05
n = 5
C*1+r^n
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 C = 1000
#       2 r = 0.05
#       3 n = 5
# ----> 4 C*1+r^n
#
# TypeError: unsupported operand type(s) for ^: 'float' and 'int'

# %% [markdown]
# #### 8. Write a short program that prompts a user to enter a stock symbol and press enter. Add each symbol entered to a variable. The program should run until the user presses the enter key without entering anything (empty string)

# %% [markdown]
# #### 9. Write the code necessary to calculate the sum of the square differences of a group of values :
# 58, 32, 37, 41, 36, 36, 54, 37, 25, 53
# ##### $\Sigma $(${x}$ - $\bar{x}$)$^2$

# %%
values = [58, 32, 37, 41, 36, 36, 54, 37, 25, 53]
mean = sum(values) / len(values)
Sum of Square = sum(x - mean) for x in values)
# Out:
#   Cell In[18], line 3
#     Sum of Square = sum(x - mean) for x in values)
#                                                  ^
# SyntaxError: unmatched ')'

# %% [markdown]
# #### 10. Opening, reading and writing files

# %%
open
view
write
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 open
# ----> 2 view
#       3 write
#
# NameError: name 'view' is not defined

# %% [markdown]
# #### 11. Create a function the will simulate rolling two die and return the value of each and and the sum

# %%
import random
Die1 = random.choice([1-6])
Die2 = random.choice([1-6])
Die1
Die2
Sum(Die1,Die2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 6
#       2 Die1 = random.choice([1-6])
#       3 Die2 = random.choice([1-6])
#       4 Die1
#       5 Die2
# ----> 6 Sum(Die1,Die2)
#
# NameError: name 'Sum' is not defined

# %% [markdown]
# #### 12. Write the code needed to evaluate whether a value in a group of values is negative or postive and prints an approriate message, i.e. postive, negative
# -1.59, 2.36, 1.69, 1.13, -0.91, 1.48, -0.34, 1.31, -0.74, 0.2

# %%
if = positive, then print (postive),if not then print(negative)
# Out:
#   Cell In[43], line 1
#     if = positive, then print (postive),if not then print(negative)
#        ^
# SyntaxError: invalid syntax

# %%
# %%sql

# %% [markdown]
# #### 14.  Complete the following:
# 1. Write a program that generates 500 random integers from 1 to n, for example, the first integer will be 1 the second will be 1 or 2, the fifth between 1 and 5, and so on.
# 2. The program should write each integer to a file
# 3. Once all integers are written close the file
#
# ##### Part 2
# 1. Open and read the file into a list
# 2. Create a line plot of the data

# %%
import random

# %%
random
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 random.ranint
#
# AttributeError: module 'random' has no attribute 'ranint'
